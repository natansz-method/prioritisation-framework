# %%
import pandas as pd

# %%
pd.read_csv("group_data.csv")
# Out:
#       Group  Solution  Complexity  Value
# 0   Group 1         1           5      5
# 1   Group 1         2           5      5
# 2   Group 1         3           5      5
# 3   Group 1         4           5      5
# 4   Group 1         5           5      5
# 5   Group 1         6           5      5
# 6   Group 1         7           5      5
# 7   Group 1         8           5      5
# 8   Group 1         9           5      5
# 9   Group 1        10           5      5
# 10  Group 1        11           5      5
# 11  Group 1        12           5      5
# 12  Group 1        13           5      5
# 13  Group 1        14           5      5
# 14  Group 1        15           5      5
# 15  Group 1        16           5      5
# 16  Group 2         1           5      5
# 17  Group 2         2           5      5
# 18  Group 2         3           5      5
# 19  Group 2         4           5      5
# 20  Group 2         5           5      5
# 21  Group 2         6           5      5
# ...
